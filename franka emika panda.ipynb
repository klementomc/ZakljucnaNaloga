# %%
from spatialmath import SE3
import roboticstoolbox as rtb
import swift

robot = rtb.models.DH.Panda()
print(robot)
T = robot.fkine(robot.qz)
print(T)
# Out:
# DHRobot: Panda (by Franka Emika), 7 joints (RRRRRRR), dynamics, geometry, modified DH parameters
# ┏━━━━━━━━┳━━━━━━━━┳━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━━┓
# ┃ aⱼ₋₁   ┃  ⍺ⱼ₋₁  ┃ θⱼ  ┃  dⱼ   ┃   q⁻    ┃   q⁺   ┃
# ┣━━━━━━━━╋━━━━━━━━╋━━━━━╋━━━━━━━╋━━━━━━━━━╋━━━━━━━━┫
# ┃    0.0 ┃   0.0° ┃  q1 ┃ 0.333 ┃ -166.0° ┃ 166.0° ┃
# ┃    0.0 ┃ -90.0° ┃  q2 ┃   0.0 ┃ -101.0° ┃ 101.0° ┃
# ┃    0.0 ┃  90.0° ┃  q3 ┃ 0.316 ┃ -166.0° ┃ 166.0° ┃
# ┃ 0.0825 ┃  90.0° ┃  q4 ┃   0.0 ┃ -176.0° ┃  -4.0° ┃
# ┃-0.0825 ┃ -90.0° ┃  q5 ┃ 0.384 ┃ -166.0° ┃ 166.0° ┃
# ┃    0.0 ┃  90.0° ┃  q6 ┃   0.0 ┃   -1.0° ┃ 215.0° ┃
# ┃  0.088 ┃  90.0° ┃  q7 ┃ 0.107 ┃ -166.0° ┃ 166.0° ┃
# ┗━━━━━━━━┻━━━━━━━━┻━━━━━┻━━━━━━━┻━━━━━━━━━┻━━━━━━━━┛
#
# ┌─────┬──────┐
# │tool │ None │
# └─────┴──────┘
#
# ┌─────┬─────┬────────┬─────┬───────┬─────┬───────┬──────┐
# │name │ q0  │ q1     │ q2  │ q3    │ q4  │ q5    │ q6   │
# ├─────┼─────┼────────┼─────┼───────┼─────┼───────┼──────┤
# │  qz │  0° │  0°    │  0° │  0°   │  0° │  0°   │  0°  │
# │  qr │  0° │ -17.2° │  0° │ -126° │  0° │  115° │  45° │
# └─────┴─────┴────────┴─────┴───────┴─────┴───────┴──────┘
#
#    0.7071    0.7071    0         0.088
#    0.7071   -0.7071    0         0
#    0         0        -1         0.823
#    0         0         0         1

# %%
#!/usr/bin/env python
"""
@author Jesse Haviland
"""

import roboticstoolbox as rp
import numpy as np

# Make a panda robot
panda = rp.models.DH.Panda()

# Init joint to the 'ready' joint angles
panda.q = panda.qr

# Make 100 random sets of joint angles
q = [0,0,0,0,0,0,0]

# Plot the joint trajectory with a 50ms delay between configurations
panda.plot(q=q)
# Out:
# PyPlot3D backend, t = 0.05, scene:
#   Panda

# %%
#!/usr/bin/env python
"""
@author Jesse Haviland
"""

import   as rp
import numpy as np

# Make a panda robot
robot = rp.models.DH.Panda()

# Init joint to the 'ready' joint angles
panda.q = panda.qr

# Make 100 random sets of joint angles
q = [0,0,0,0,0,0,0]
panda.plot(q)
# Out:
# PyPlot3D backend, t = 0.05, scene:
#   Panda

# %%
from spatialmath import SE3
import numpy as np
T = np.array([[1,0,0,0.5,],[0,1,0,0],[0,0,1,0.926],[0,0,0,1]])
sol = robot.ikine_LM(T)         # solve IK
print(sol)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\UPORAB~1\AppData\Local\Temp/ipykernel_8760/3542154818.py in <module>
#       2 import numpy as np
#       3 T = np.array([[1,0,0,0.5,],[0,1,0,0],[0,0,1,0.926],[0,0,0,1]])
# ----> 4 sol = robot.ikine_LM(T)         # solve IK
#       5 print(sol)
#
# C:\ProgramData\Anaconda3\lib\site-packages\roboticstoolbox\robot\IK.py in ikine_LM(self, T, q0, mask, ilimit, rlimit, tol, L, Lmin, search, slimit, transpose, end)
#     248
#     249         if not isinstance(T, SE3):
# --> 250             raise TypeError("argument must be SE3")
#     251
#     252         if isinstance(self, rtb.DHRobot):
#
# TypeError: argument must be SE3

# %%
import numpy as np
import roboticstoolbox as rp

panda = rp.models.DH.Panda()

q = [0,0,0,0,0,0,0]

panda.plot(q)
# Out:
# PyPlot3D backend, t = 0.05, scene:
#   Panda
